# %%
import pandas as pd

# %%
#import dataframe
df_apart = pd.read_csv('dados_apartamentos.csv',  encoding = "ISO-8859-1", sep=';', header=0)
df_houses = pd.read_csv('houses_dados.csv',encoding = "ISO-8859-1", sep=';', header=0)

# %%
#drop empty columns
df_apart = df_apart.drop(['Unnamed: 13','Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17','Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21','Unnamed: 22', 'Unnamed: 23'], axis = 1)

# %%
# clean sqm from Areas (sqm) 
df_apart['Areas (sqm)'] = df_apart['Areas (sqm)'].str.extract('(\d+)', expand=False)

# %%
df_apart.head()
# Out:
#   Entry Date Property type Tipology Condition              Location   Price  \
# 0   20/07/20    Apartments       T2      Used  Aveiro,Aveiro,Aradas  145000
# 1   20/07/20    Apartments       T2      Used  Aveiro,Aveiro,Aradas  155000
# 2   20/07/20    Apartments       T2      Used  Aveiro,Aveiro,Aradas  118000
# 3   20/07/20    Apartments       T2      Used  Aveiro,Aveiro,Aradas  185000
# 4   20/07/20    Apartments       T2       New  Aveiro,Aveiro,Aradas  295000
#
#   Areas (sqm)  euros/sqm  Built year Latitude Longitude Characteristics  \
# 0          96       1518         NaN      NaN       NaN             NaN
# 1         119       1303         NaN      NaN       NaN             NaN
# 2          72       1639         NaN      NaN       NaN             NaN
# 3          90       2056         NaN      NaN       NaN             NaN
# 4         126       2351         NaN      NaN       NaN             NaN
#
#                                          Mister URL
# 0  http://primeavm.prime-yield.com/property/5788813
# 1  http://primeavm.prime-yield.com/property/5788814
# 2  http://primeavm.prime-yield.com/property/5788815
# 3  http://primeavm.prime-yield.com/property/5788816
# 4  http://primeavm.prime-yield.com/property/5788817

# %%
df_houses.head()
# Out:
#   Entry Date Property type Tipology Condition Condition.1  \
# 0   21/02/21        Houses       T4      Used        Used
# 1   21/02/21        Houses       T3      Used        Used
# 2   21/02/21        Houses       T3      Used        Used
# 3   21/02/21        Houses       T4      Used        Used
# 4   21/02/21        Houses       T4      Used        Used
#
#                               Location   Price Areas (sqm)    Û/sqm  \
# 0  Aveiro,êlhavo,Gafanha da Encarnao  570000         175  3257,14
# 1  Aveiro,êlhavo,Gafanha da Encarnao  320000         258  1240,31
# 2  Aveiro,êlhavo,Gafanha da Encarnao  315000         140  2250,00
# 3  Aveiro,êlhavo,Gafanha da Encarnao  237000         194  1221,65
# 4  Aveiro,êlhavo,Gafanha da Encarnao  580000         193  3005,18
#
#   Built year Distance Latitude Longitude Characteristics
# 0        NaN      NaN      NaN       NaN             NaN
# 1        NaN      NaN      NaN       NaN             NaN
# 2        NaN      NaN      NaN       NaN             NaN
# 3        NaN      NaN      NaN       NaN             NaN
# 4        NaN      NaN      NaN       NaN             NaN
